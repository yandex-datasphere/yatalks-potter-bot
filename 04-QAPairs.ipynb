# %% [markdown]
# ## 04. Извлечение вопрос-ответных пар из текста
#
# Для тренировки Yandex GPT нам необходимо сформировать множество вопрос-ответных пар. Чтобы сделать это на основе текста, мы попробуем использовать большие языковые модели.
#
# Для начала, поэкспериментируем с Yandex GPT:

# %%
import json
from langchain.llms import YandexGPT

config = json.load(open("config.json"))

gpt = YandexGPT(api_key=config['api_key'])

# %% [markdown]
# Для извлечения вопрос-ответных пар поэкспериментируем с разными запросами. Помните про основные правила промпт-инжиниринга:
#
# * Четкое выделение входных данных
# * Подробные инструкции
# * Указание желаемого формата данных на выходе
# * Экспериментируйте с разными вариантами промптов
# * Экспериментируйте с температурой

# %%
prompt="""
Ниже в тройных обратных кавычках приводится некоторый текст.
Твоя задача - внимательно прочитать
текст и сформулировать как можно больше (но не менее 10) вопросов к 
этому тексту. Пожалуйста, запиши вопросы и ответы на них (содержащиеся 
в тексте) в формате JSON следующим образом:
[
    {"request":"вопрос 1","response":"ответ 1"},
    {"request":"вопрос 2","response":"ответ 2"},
    ...
].
Напиши только те вопросы, ответы на которые содержатся в тексте. 
Пожалуйста, формулируй вопросы и ответы как можно более подробным образом.
Постарайся, чтобы в вопросе содержалась необходимая информация об объекта, 
например, не спрашивай "как произносится заклинание?", а пиши подробно:
"как произносится заклинание невидимости".
Вот фрагмент странички:
```
{PAGE}
```
"""

# %% [markdown]
# Используйте код ниже, чтобы извлекать вопрос-ответные пары из страничек и сразу смотреть результаты. Мы используем класс `SimpleJsonOutputParser` из LangChain, чтобы лишний раз убедиться, что результат LLM представлен в формате JSON.
#
# Скорее всего, вы обнаружите следующее:
# * Некоторые странички слишком короткие, их нет смысла обрабатывать. Можно обрабатывать странички по частям, например, сначала брать все заклинания (маска файлов `content/text/Закли*`), потом - книги/фильмы (маска файлов `content/text/Гарри Поттер и*`) и т.д.
# * Один промпт не подходит на все случаи жизни. Для каждого типа страниц может помочь слегка модифицировать промпт.
# * Некоторые вопросы могут иметь вид: `{'request': 'Как называется заклинание?', 'response': 'Заклинание воспламенения'}` - они не очень подходят для тренировки модели, поскольку в вопросе не упоминается требуемое заклинание. Нужно попытаться как-то так сформулировать промпт, чтобы вопросы были как можно более специфическими.
#
# Все вопрос-ответные пары мы запоминаем в большом словаре `pairs`. Можно инициализировать словарь только один раз, и затем уже пополнять его, запуская несколько раз цикл обхода страничек:

# %%
pairs = {}

# %%
import os,time
from glob import glob
from grpc._channel import _MultiThreadedRendezvous

from langchain.output_parsers.json import SimpleJsonOutputParser

jp = SimpleJsonOutputParser()
gpt.temperature = 0.1

def process_files(fns):
  for fn in fns:
    if fn in pairs.keys():
        print(f"Already processed: {fn}")
        continue
    print(f'Processing {fn}')
    text = open(fn,'r',encoding='utf-8').read()
    p = prompt.replace('{PAGE}',text)
    try:
        res = gpt(p)
    except _MultiThreadedRendezvous as e:
        print(f"Error processing {fn}")
        continue
    j = jp.parse(res)
    print(j)
    if j is not None and len(j)>0:
        pairs[fn] = j
    time.sleep(1)

process_files(glob('content/text/Закли*'))
# Out:
# Processing content/text\Заклинание «Сито из котла».txt
# []
# Already processed: content/text\Заклинание анимагии.txt
# Already processed: content/text\Заклинание вечного приклеивания.txt
# Already processed: content/text\Заклинание воспламенения.txt
# Already processed: content/text\Заклинание гидрокинеза.txt
# Already processed: content/text\Заклинание головного пузыря.txt
# Already processed: content/text\Заклинание для мытья посуды.txt
# Already processed: content/text\Заклинание для окрашивания Коросты в жёлтый цвет.txt
# Already processed: content/text\Заклинание для очистки картофеля.txt
# Already processed: content/text\Заклинание для устранения заклинившего реверса.txt
# Already processed: content/text\Заклинание заметания следов.txt
# Already processed: content/text\Заклинание Заморозки.txt
# Processing content/text\Заклинание запечатывания комнаты.txt
# []
# Processing content/text\Заклинание запечатывания пергамента.txt
# []
# Already processed: content/text\Заклинание зонта.txt
# Already processed: content/text\Заклинание Компаса.txt
# Already processed: content/text\Заклинание нагревания воды.txt
# Already processed: content/text\Заклинание невидимого хлыста.txt
# Already processed: content/text\Заклинание незримого расширения.txt
# Already processed: content/text\Заклинание ножниц.txt
# Already processed: content/text\Заклинание Обращения.txt
# Already processed: content/text\Заклинание опрятности Долорес Амбридж.txt
# Already processed: content/text\Заклинание открывания дверей.txt
# Already processed: content/text\Заклинание отпугивания пауков.txt
# Already processed: content/text\Заклинание отслеживания.txt
# Already processed: content/text\Заклинание пальцекусания.txt
# Already processed: content/text\Заклинание Патронуса.txt
# Already processed: content/text\Заклинание перемещения в зеркало Еиналеж.txt
# Already processed: content/text\Заклинание письма на доске.txt
# Already processed: content/text\Заклинание Подзаправки.txt
# Already processed: content/text\Заклинание Полёта.txt
# Processing content/text\Заклинание превращения дикобраза в игольницу.txt
# [{'request': 'Как называется заклинание?', 'response': 'Превращение дикобраза в игольницу'}, {'request': 'Кто обучал второкурсников этому заклинанию?', 'response': 'Минерва Макгонагалл'}, {'request': 'Что означает слово «hystrix»?', 'response': 'Дикобраз'}, {'request': 'Что превращает заклинание?', 'response': 'Вещи в игольницы'}, {'request': 'Когда второкурсники начали изучать это заклинание?', 'response': 'В 1985-1986 годах'}, {'request': 'Что означает слово «Лапифорс»?', 'response': 'Кролик'}, {'request': 'Что означает слово «Авифорс»?', 'response': 'Птица'}, {'request': 'Что может быть связано с этим заклинанием?', 'response': 'Заклинание превращения ежей в игольницы'}, {'request': 'Когда четверокурсники начали изучать заклинание превращения ежей в игольницы?', 'response': 'В 1994-1995 годах'}, {'request': 'Где впервые появилось это заклинание?', 'response': 'В игре «Harry Potter: Hogwarts Mystery»'}]
# Already processed: content/text\Заклинание превращения жабы в поганку.txt
# Already processed: content/text\Заклинание превращения карликового пушистика в пресс-папье.txt
# Already processed: content/text\Заклинание превращения мыши в табакерку.txt
# Already processed: content/text\Заклинание превращения неразлучника в любовное письмо.txt
# Already processed: content/text\Заклинание превращения пешки в ферзя.txt
# Already processed: content/text\Заклинание превращения пирожного в фею.txt
# Already processed: content/text\Заклинание превращения совы в театральный бинокль.txt
# Already processed: content/text\Заклинание превращения флоббер-червя в оладью.txt
# Already processed: content/text\Заклинание превращения хорька в метёлку.txt
# Already processed: content/text\Заклинание превращения хорька в человека.txt
# Already processed: content/text\Заклинание превращения чайника в хорька.txt
# Processing content/text\Заклинание превращения чайника в черепаху.txt
# [{'request': 'Как называется заклинание?', 'response': 'Заклинание превращения чайника в черепаху'}, {'request': 'Какой тип заклинания?', 'response': 'Трансфигурационное, Трансформация'}, {'request': 'Какой эффект заклинания?', 'response': 'Превращает чайник в черепаху'}, {'request': 'Какого цвета черепаха?', 'response': 'Оранжевого'}, {'request': 'В каком произведении встречается это заклинание?', 'response': 'Гарри Поттер и узник Азкабана'}, {'request': 'В какой игре встречается это заклинание?', 'response': 'Гарри Поттер и Орден Феникса (игра)'}, {'request': 'В каком приложении встречается это заклинание?', 'response': 'Harry Potter: Hogwarts Mystery'}, {'request': 'Когда появилось это заклинание?', 'response': 'Третьекурсники в Хогвартсе должны были продемонстрировать владение данным заклинанием во время выпускного экзамена по Трансфигурации'}, {'request': 'Какие последствия могут быть при неполной трансфигурации?', 'response': 'Черепаха будет дышать паром, вместо хвоста у неё будет носик чайника или же её панцирь окрасится синий узор от чайника'}, {'request': 'Как называется рок-группа, связанная с этим заклинанием?', 'response': 'Teapot to tortoise'}, {'request': 'Сколько песен у этой группы на YouTube?', 'response': 'Три песни'}, {'request': 'Откуда родом эта группа?', 'response': 'Ливерпуль'}]
# Already processed: content/text\Заклинание превращения чашки в песчанку.txt
# Already processed: content/text\Заклинание превращения человека в хорька.txt
# Already processed: content/text\Заклинание превращения черепахи в трубу.txt
# Already processed: content/text\Заклинание превращения шара для боулинга в воздушный шарик.txt
# Already processed: content/text\Заклинание превращения шоколадного котелка в капусту.txt
# Processing content/text\Заклинание призыва молнии Геллерта Грин-де-Вальда.txt
# [{'request': 'Как называется заклинание?', 'response': 'Заклинание призыва молнии Геллерта Грин-де-Вальда'}, {'request': 'Какой тип чар?', 'response': 'Тёмные чары'}, {'request': 'Какой эффект у заклинания?', 'response': 'Создает большую белую молнию'}, {'request': 'Какого цвета молния?', 'response': 'Синевато-белая'}, {'request': 'Кто использовал это заклинание?', 'response': 'Геллерт Грин-де-Вальд'}, {'request': 'Когда Геллерт Грин-де-Вальд использовал это заклинание?', 'response': 'В 1926 году'}, {'request': 'Против кого было использовано заклинание?', 'response': 'Ньюта Саламандера'}, {'request': 'Где было использовано заклинание?', 'response': 'Во время атаки обскура на Нью-Йорк'}, {'request': 'В каком произведении впервые упоминается это заклинание?', 'response': 'Фантастические твари и где они обитают: Оригинальный сценарий'}, {'request': 'В каком произведении упоминается это заклинание?', 'response': 'Фантастические твари и где они обитают'}]
# Already processed: content/text\Заклинание против списывания.txt
# Already processed: content/text\Заклинание Раздувания.txt
# Already processed: content/text\Заклинание роста ногтей на ногах.txt
# Already processed: content/text\Заклинание создания воды.txt
# Already processed: content/text\Заклинание стрелы.txt
# Processing content/text\Заклинание телепортации.txt
# [{'request': 'Как называется заклинание телепортации?', 'response': 'Заклинание телепортации'}, {'request': 'Что делает заклинание телепортации?', 'response': 'Перемещает объект из одного места в другое'}, {'request': 'Кто использовал заклинание телепортации в 1996 году?', 'response': 'Альбус Дамблдор'}, {'request': 'Куда Альбус Дамблдор отправил вещи Гарри Поттера?', 'response': 'В Нору'}, {'request': 'Почему Альбус Дамблдор решил отправить вещи Гарри Поттера в Нору?', 'response': 'Чтобы попытаться уговорить Горация Слизнорта занять должность преподавателя ЗОТИ в Хогвартсе'}, {'request': 'В каком году Альбус Дамблдор отправил вещи Гарри Поттера в Нору?', 'response': 'В 1996 году'}, {'request': 'В каком произведении Гарри Поттер использовал заклинание телепортации?', 'response': 'Гарри Поттер и Принц-полукровка'}, {'request': 'В каком фильме Гарри Поттер использовал заклинание телепортации?', 'response': 'Гарри Поттер и Принц-полукровка (фильм)'}, {'request': 'Как называется глава в книге, где Гарри Поттер использовал заклинание телепортации?', 'response': 'Глава 3. Будет — не будет'}, {'request': 'Как называется произведение, где упоминается заклинание телепортации?', 'response': 'Гарри Поттер и Принц-полукровка'}]
# Already processed: content/text\Заклинание тушения огня.txt
# Processing content/text\Заклинание, запускающее изображение лица Златопуста Локонса.txt
# [{'request': 'Как называется заклинание?', 'response': 'Заклинание, запускающее изображение лица Златопуста Локонса'}, {'request': 'Кто создал заклинание?', 'response': 'Златопуст Локонс'}, {'request': 'Что делает заклинание?', 'response': 'Запускает в воздух изображение лица Златопуста Локонса'}, {'request': 'Когда было создано заклинание?', 'response': 'Между 1975 и 1982 годами'}, {'request': 'Что известно о применении заклинания?', 'response': 'Ничего не известно'}, {'request': 'Как называется заклинание на английском языке?', 'response': "Gilderoy Lockhart's holographic spell"}, {'request': 'Как заклинание напоминает Чёрную метку?', 'response': 'Отображение лица Златопуста Локонса'}, {'request': 'Что такое Чёрная метка?', 'response': 'Изображение лица'}, {'request': 'Что такое сигнальные заклинания?', 'response': 'Неизвестно'}, {'request': 'Что такое формула заклинания?', 'response': 'Неизвестна'}]
# Already processed: content/text\Заклинание.txt
# Already processed: content/text\Заклинания воспламенения.txt
# Processing content/text\Заклинания защиты и запугивания.txt
# []
# Already processed: content/text\Заклинания.txt

# %% [markdown]
# Также есть несколько страниц, по которым важно построить вопрос-ответные пары:

# %%
prompt="""
Ниже в тройных обратных кавычках приводится список разных объектов.
Твоя задача - внимательно прочитать
текст и сформулировать как можно больше (но не менее 10) вопросов к 
этому тексту. Пожалуйста, запиши вопросы и ответы на них (содержащиеся 
в тексте) в формате JSON следующим образом:
[
    {"request":"вопрос 1","response":"ответ 1"},
    {"request":"вопрос 2","response":"ответ 2"},
    ...
].
Напиши только те вопросы, ответы на которые содержатся в тексте. 
Пожалуйста, формулируй вопросы и ответы как можно более подробным образом.
Постарайся, чтобы в вопросе содержалась необходимая информация об объекте, 
например, не спрашивай "как произносится заклинание?", а пиши подробно:
"как произносится заклинание невидимости".
Вот список:
```
{PAGE}
```
"""

cool_pages = [
    'Великие волшебники', 'Список волшебных палочек', 'Список заклинаний',
    'Список зелий', 'Список волшебных существ Саламандера'
]

process_files([f'content/text/{x}.txt' for x in cool_pages])
# Out:
# Processing content/text/Великие волшебники.txt
# Error processing content/text/Великие волшебники.txt
# Already processed: content/text/Список волшебных палочек.txt
# Processing content/text/Список заклинаний.txt
# None
# Processing content/text/Список зелий.txt
# [{'request': 'какие зелья упоминаются в книгах о Гарри Поттере?', 'response': 'Амортенция, антисглазной лак, бедовый лосьон, бодроперцовое зелье, болтливое зелье, болтушка для молчунов, вечные прочные ресницы, волчье противоядие, волшебный искристый порошок, всевозможно зелье, гарантированный десятисекундный прыщевыводитель, гербицид, глазная сыворотка «Любовь слепа», доксицид, долголетние эликсиры, драконий тоник, дурманящая настойка, душильный газ, дыбоволосное зелье, елейная смазка Григория, желчь броненосца, животворящий эликсир, зелье взрыва, зелье для излечения фурункулов, зелье для проявки фотографий, зелье забывчивости, зелье красоты, зелье Мопсуса, зелье невидимости, зелье необычайной силы, зелье от икоты, зелье от кашля, зелье п
ёппи, Шпротва, Штырехвост.'}, {'request': 'Какие существа относятся к категории XX?', 'response': 'К категории XX относятся следующие существа: Авгурей, Бес малый, Болтрушайка, Глиноклок, Гном садовый, Гриндилоу, Диринар, Клабберт, Лукотрус, Лунный телец, Пушистики, Рамора, Упырь, Фея, Чизпурфл.'}, {'request': 'Какие существа относятся к категории X?', 'response': 'К категории X относятся следующие существа: Мурлокомль, Флоббер-червь.'}]

# %% [markdown]
# Запишем на всякий случай получившийся список pairs:

# %%
with open('data/pairs.json','w',encoding='utf-8') as f:
    json.dump(pairs,f,ensure_ascii=False)

# %% [markdown]
# Теперь преобразуем всё к формату, в котором Yandex GPT принимает фразы для до-обучения:

# %%
res = []
stop = ['как называется заклинание?','как произносится заклинание?']
for _,p in pairs.items():
    for d in p:
        if 'request' in d and 'response' in d and not(d['request'].lower() in stop):
            res.append(d)
            
print(f"Всего {len(res)} вопрос-ответных пар")
# Out:
# Всего 720 вопрос-ответных пар

# %% [markdown]
# Запишем результат на диск:

# %%
with open('data/pairs_for_train_ygpt.json','w',encoding='utf-8') as f:
    json.dump(res,f,ensure_ascii=False)

# %% [markdown]
# ### Пробуем диалоговые LLM
#
# Для получения дополнительного списка вопрос-ответных пар можно попробовать использовать диалоговые модели с длинным контекстом, например, [Claude 2](https://claude.ai) (*не забудьте про [VPN](https://veepn.com/home/)!**). Для этого сформируем несколько файлов с текстом по определённым темам, которые мы затем загрузим в модель вручную:

# %%
page_classes = {
    "Заклинания" : "Заклинани*",
    "Практикумы" : "Практикум*",
    "Портреты" : "Портрет*",
    "Палочки" : "Палочка*",
    "Отделы" : "Отдел*",
    "Книги" : "Книга*",
    "Классы" : "Класс*",
    "Зелья" : "Зелье*",
    "Заклятия" : "Заклятие*",
    "Декреты" : "Декрет*",
    "Фильмы" : "Гарри поттер и*(фильм)*"
}

for fn,mask in page_classes.items():
    with open(f'content/{fn}.txt','w',encoding='utf-8') as f:
        for ffn in glob(f'content/text/{mask}'):
            f.write(open(ffn).read())

# %% [markdown]
# Полученные файлы мы можем по-очереди загружать в модель Claude 2, и просить его написать вопросы к тексту, используя, например, такой промпт:
#
# ```
# В приложенном файле содержится информация из вселенной Гарри Поттера.
# Твоя задача - внимательно прочитать
# текст и сформулировать как можно больше (но не менее 50) вопросов к
# этому тексту. Пожалуйста, запиши вопросы и ответы на них (содержащиеся
# в тексте) в формате JSON следующим образом:
# [
#     {"request":"вопрос 1","response":"ответ 1"},
#     {"request":"вопрос 2","response":"ответ 2"},
#     ...
# ].
# Напиши только те вопросы, ответы на которые содержатся в тексте.
# Пожалуйста, формулируй вопросы и ответы как можно более подробным образом.
# ```
#
# Все вопросы поместим в файл `data/pairs_for_train_claude.json`. В этом репозитории уже содержится файл с такими вопросами, посмотрим на него:

# %%
rr = json.load(open('data/pairs_for_train_claude.json'))
print(len(rr))
# Out:
# 310

# %% [markdown]
# Объединим эти два файла в один, который затем используем для до-обучения модели:

# %%
d1 = json.load(open('data/pairs_for_train_ygpt.json'))
d2 = json.load(open('data/pairs_for_train_claude.json'))
with open('data/pairs_for_train.json', 'w', encoding='utf-8') as f:
    json.dump(d1 + d2, f, ensure_ascii=False)

print(f"Всего пар: {len(d1+d2)}")
# Out:
# Всего пар: 1030
